# %%
from matplotlib.pylab import *

# %%
pts = loadtxt("result.dat")
# !ls
# Out:
# cluster.ipynb  csv  panda.ipynb  result.dat

# %%
G=[ pts[pts[:,2]==k] for k in range(5)]
[ scatter(G[i][:,0],G[i][:,1]) for i in range(5)]
