# %%
import pandas as pd

emp = pd.read_csv("./csv/emp.csv")

emp['sal'].min

# %%
import pandas as pd 

emp = pd.read_csv("./csv/emp.csv")

a = emp.groupby('job')['sal'].min().reset_index()
a1 = a.sort_values(by='sal', ascending=True)
a1.columns = ["직원", '최소월급']
a1[:][a1['최소월급'] >= 1200]
# Out:
#           직원  최소월급
# 4   SALESMAN  1250
# 2    MANAGER  2450
# 0    ANALYST  3000
# 3  PRESIDENT  5000

# %%
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1982-12-22  3000     NaN      20
# ...

# %%
import pandas as pd

emp = pd.read_csv('./csv/emp.csv')

#emp.info()
emp['hiredate'] = pd.to_datetime(emp['hiredate'])
emp['hire_year'] = emp['hiredate'].dt.year
emp
# Out:
#     empno   ename        job     mgr   hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0 1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0 1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0 1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0 1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0 1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0 1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0 1982-12-22  3000     NaN      20
# ...

# %%
import pandas as pd

emp = pd.read_csv('./csv/emp.csv')

a = emp.groupby('job')['sal'].sum().reset_index()
a1 = a.sort_values(by='sal', ascending=False)
a2 = a1[:][a1['job'] != 'SALESMAN']
a2[:][a2['sal']>=5000]
# Out:
#          job   sal
# 2    MANAGER  8275
# 0    ANALYST  6000
# 3  PRESIDENT  5000

# %%
import pandas as pd

emp20 = pd.read_csv("./csv/emp20.csv", encoding='euckr')

emp20['age'].max()
# Out:
# np.int64(37)

# %%
import pandas as pd 

emp = pd.read_csv("./csv/emp.csv")
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1982-12-22  3000     NaN      20
# ...

# %%
emp.groupby('job')['sal'].max().reset_index()
# Out:
#          job   sal
# 0    ANALYST  3000
# 1      CLERK  1300
# 2    MANAGER  2975
# 3  PRESIDENT  5000
# 4   SALESMAN  1600

# %%
import pandas as pd

tit = pd.read_csv("./csv/train.csv")
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit.groupby('Pclass')['Fare'].max().reset_index()
# Out:
#    Pclass      Fare
# 0       1  512.3292
# 1       2   73.5000
# 2       3   69.5500

# %%
a = emp20.groupby('telecom')['age'].max().reset_index() 
a
# Out:
#   telecom  age
# 0      kt   33
# 1      lg   33
# 2      sk   37

# %%
a.columns = ["통신사", "최대나이"]
a
# Out:
#   통신사  최대나이
# 0  kt    33
# 1  lg    33
# 2  sk    37

# %%
import pandas as pd

emp = pd.read_csv("./csv/emp.csv")
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1982-12-22  3000     NaN      20
# ...

# %%
emp1 = emp.groupby('job')['sal'].min().reset_index()

# %%
emp1.columns = ("직업","최소월급")
emp1.sort_values(by='최소월급', ascending=True)
# Out:
#           직업  최소월급
# 1      CLERK   800
# 4   SALESMAN  1250
# 2    MANAGER  2450
# 0    ANALYST  3000
# 3  PRESIDENT  5000

# %%
# tit.info()
tit['Name'].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
import pandas as pd 

emp20 = pd.read_csv("./csv/emp20.csv", encoding='euckr')

#emp20
emp20['telecom'] = emp20['telecom'].str.upper()
emp20[['ename', 'telecom']]
# pd.concat( [emp20.ename, emp20.telecom.str.upper()], axis=1) #axis -> 0 위아래, axis -> 1 양옆으로 붙이기
# Out:
#    ename telecom
# 0    홍길동      KT
# 1    이순신      SK
# 2    정약용      SK
# 3    김유신      SK
# 4    장보고      KT
# 5    정몽주      SK
# 6    문익점      SK
# 7     황희      SK
# 8    한석봉      SK
# 9    황진이      SK
# 10   안중근      KT
# 11   김옥균      SK
# 12   윤동주      KT
# 13   안창호      SK
# 14   김좌진      SK
# 15   김두한      SK
# 16    논개      KT
# 17    최영      KT
# 18   김부식      KT
# 19   장영실      LG
# 20   김홍도      SK

# %%
emp = pd.read_csv("./csv/emp.csv")
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1982-12-22  3000     NaN      20
# ...

# %%
emp['ename'].str.capitalize()
# Out:
# 0       King
# 1      Blake
# 2      Clark
# 3      Jones
# 4     Martin
# 5      Allen
# 6     Turner
# 7      James
# 8       Ward
# 9       Ford
# 10     Smith
# 11     Scott
# 12     Adams
# 13    Miller
# Name: ename, dtype: object

# %%
emp[['ename', 'sal']] [emp['ename'].str.lower() == "scott"]
#emp[['ename', 'sal']] [emp.ename.str.lower() == 'scott']
# Out:
#     ename   sal
# 11  SCOTT  3000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 from sklearn.preprocessing import MinMaxScaler
#       3 scaler = MinMaxScaler()
# ----> 4 scaler.fit(df)
#
# NameError: name 'df' is not defined

# %%
emp.info()

# %%
import pandas as pd

emp = pd.read_csv("./csv/emp.csv")
emp['ename'].str.slice(start = 1, stop = 2)

# %%
emp20

# %%
import pandas as pd

emp20 = pd.read_csv('./csv/emp20.csv', encoding='euckr')

a = emp20[['ename', 'age','address']][emp20['address'].str.slice(start=0, stop=3) != '서울시']
a.sort_values(by='age', ascending=False)

# %%
import pandas as pd 

emp20 = pd.read_csv("./csv/emp20.csv", encoding='euckr')
emp20['telecom'] = emp20['telecom'].str.capitalize()
# emp20[['ename', 'telecom']]
emp20[['ename', 'telecom']]

# %%
import pandas as pd 

mtcars = pd.read_csv('https://raw.githubusercontent.com/Datamanim/dataq/main/mtcars.csv',index_col=0)
mtcars

# %%
print(mtcars)

# %%
df = mtcars[['qsec']]
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df) 

mtcars['qsec_scaled'] = scaler.transform(df)
mtcars

# %%
a = mtcars[:] [mtcars['qsec_scaled'] > 0.5]
a

# %%
boston[['id', 'price'] ] [boston['price'].between(10,30) ]

# %%
boston[:] [boston['price'].between(10,30) ]

# %%
boston[['id', 'price'] ] [ ~ boston['price'].between(10,30) ]

# %%
import pandas as pd

emp20 = pd.read_csv("./csv/emp20.csv", encoding="euckr")

emp20

# %%
emp20[['ename', 'telecom']][ ~ emp20['telecom'].isin(['kt', 'lg'])]

# %%
emp20[['ename', 'age']][emp20['age'].between(20,29)]

# %%
import pandas as pd

emp = pd.read_csv("./csv/emp.csv")

emp

# %%
emp[['ename', 'job']][emp['job'].isin(["SALESMAN","ANALYST"])]

# %%
print(emp.info)

# %%
import pandas as pd 

emp = pd.read_csv("./csv/emp.csv")

emp[['ename', 'comm']][ ~ emp['comm'].isnull()]

# %%
emp[['ename']][emp['ename'].apply(lambda x : x[0] == "A")]

# %%
emp[['ename']][emp['ename'].apply(lambda x : x[-1] == "T")]

# %%
emp20

# %%
emp20[['ename', 'age']][emp20['ename'].apply(lambda x : x[0] == "김")]

# %%
emp20[['ename', 'age']][ ~ emp20['ename'].apply(lambda x : x[0] == "김")]

# %%
emp

# %%
emp[['ename','sal','job']][emp['job'] == "SALESMAN"].sort_values(by="sal", ascending=False)

# %%
emp[['ename', 'sal']].sort_values( by = 'sal', ascending=False)

# %%
emp20

# %%
result = emp20[['ename','age','telecom']][emp20['telecom'] != "kt"]

result.sort_values(by='age', ascending=False)

# %%
print(emp['hiredate'])

# %%
emp['hiredate'] = pd.to_datetime(emp['hiredate'])

# %%
emp[['ename', 'hiredate']][emp['hiredate'].between('1981-01-01','1981-12-31')]

# %%
result = emp[['ename', 'job', 'hiredate']][emp['job'] == 'SALESMAN']

result[:][emp['hiredate'].between('1981-01-01', '1981-12-31')]

# %%
emp['deptno'].unique()

emp['deptno']

# %%
import pandas as pd

tit = pd.read_csv("./csv/train.csv")

tit

# %%
tit['Pclass'].unique()

tit['Pclass']

# %%
import pandas as pd

emp = pd.read_csv("./csv/emp.csv")
emp['ename_len'] = emp.ename.str.len()
emp[['ename', 'ena_len']]

# %%
emp['ename_len'] = emp.ename.str.len()
emp[['ename', 'ename_len']].sort_values(by='ename_len', ascending=False)

# %%
tit = pd.read_csv("./csv/train.csv")
tit

# %%
tit['Name_len'] = tit['Name'].str.len()
tit[['Name', 'Name_len']].sort_values(by='Name_len', ascending=False)

# %%
emp
#emp[['ename', 'sal']][emp['ename'].str.find('M') <= 0]

# %%
emp['sal'] = emp['sal'].astype(str)
emp['sal_reprice'] = emp['sal'].str.replace("0", "*")
emp[['ename', 'sal_reprice']]
